# %% [markdown]
# # 🏠 Data Cleaning Housing Dataset
#
# ### 👩 Nama : Alini Syawalia Riski Fenanda
# ### 🆔 NIM : 240401010213
# ### 📚 Mata Kuliah : Data Science
#
# ---
#
# ## 📌 Deskripsi Praktikum
# Praktikum ini bertujuan untuk melakukan proses *data cleaning* pada dataset properti perumahan yang memiliki berbagai masalah kualitas data seperti:
#
# - Missing values
# - Data duplikat
# - Outlier
# - Inkonsistensi format string
#
# Dataset yang telah dibersihkan nantinya akan digunakan untuk analisis data lebih lanjut.

# %% [markdown]
# ## STEP 1 - Import Library
# Mengimpor library yang dibutuhkan untuk proses data cleaning, yaitu pandas untuk manipulasi data, numpy untuk operasi numerik, dan scipy untuk fungsi statistik tambahan.

# %%
import pandas as pd
import numpy as np
from scipy.stats.mstats import winsorize

# %% [markdown]
# # 🔹 STEP 2 - Load Dataset
#
# Dataset `housing_dirty.csv` dimuat ke dalam DataFrame menggunakan pandas agar dapat diproses lebih lanjut.

# %%
df = pd.read_csv('housing_dirty.csv')

print("✅ Dataset berhasil dimuat")
df.head()
# Out:
# ✅ Dataset berhasil dimuat
#    id  luas_m2  harga_juta   kota  kamar  tahun_bangun kondisi
# 0   1    297.0      1084.0  jogja    2.0          2000    baik
# 1   2    254.0       761.0  Medan    NaN          1995   Bagus
# 2   3    249.7       895.0  Depok    NaN          1983    baik
# 3   4     49.7       178.0    YGY    5.0          2013    baik
# 4   5    133.4       424.0  Medan    5.0          2004  Sedang

# %% [markdown]
# # 🔹 STEP 3 - Eksplorasi Dataset
#
# Eksplorasi awal dilakukan untuk memahami kondisi dataset sebelum proses cleaning.
#
# Pengecekan meliputi:
# - Struktur data
# - Statistik deskriptif
# - Missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            130 non-null    int64
#  1   luas_m2       112 non-null    float64
#  2   harga_juta    113 non-null    float64
#  3   kota          130 non-null    object
#  4   kamar         120 non-null    float64
#  5   tahun_bangun  130 non-null    int64
#  6   kondisi       130 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                id      luas_m2    harga_juta       kamar  tahun_bangun
# count  130.000000   112.000000  1.130000e+02  120.000000    130.000000
# mean    65.500000   267.627679  8.856325e+05    3.433333   2062.638462
# std     37.671829   885.664181  9.407144e+06    1.776283    701.684043
# min      1.000000   -50.000000 -5.000000e+02    1.000000   1890.000000
# 25%     33.250000    87.050000  3.450000e+02    2.000000   1991.250000
# 50%     65.500000   193.800000  6.550000e+02    4.000000   2002.000000
# 75%     97.750000   280.675000  9.550000e+02    5.000000   2011.750000
# max    130.000000  9500.000000  1.000000e+08    6.000000   9999.000000

# %%
df.isnull().sum()
# Out:
# id               0
# luas_m2         18
# harga_juta      17
# kota             0
# kamar           10
# tahun_bangun     0
# kondisi          0
# dtype: int64

# %% [markdown]
# # 🔹 STEP 4 - Menghapus Data Duplikat
#
# Data duplikat dapat menyebabkan hasil analisis menjadi tidak akurat.
#
# Oleh karena itu dilakukan penghapusan data yang memiliki isi baris yang sama.

# %%
print("Jumlah data sebelum:", df.shape)

df.drop_duplicates(inplace=True)

print("Jumlah data sesudah:", df.shape)
# Out:
# Jumlah data sebelum: (130, 7)
# Jumlah data sesudah: (130, 7)

# %% [markdown]
# # 🔹 STEP 5 - Normalisasi String
#
# Normalisasi dilakukan untuk menyamakan format penulisan data string.
#
# Contoh:
# - jakarta → Jakarta
# - BAIK → baik

# %%
df['kota'] = df['kota'].str.strip().str.title()
df['kondisi'] = df['kondisi'].str.strip().str.lower()

df[['kota', 'kondisi']].head()
# Out:
#     kota kondisi
# 0  Jogja    baik
# 1  Medan   bagus
# 2  Depok    baik
# 3    Ygy    baik
# 4  Medan  sedang

# %% [markdown]
# # 🔹 STEP 6 - Menangani Missing Values
#
# Missing values ditangani menggunakan:
# - Median → untuk data numerik
# - Modus → untuk data kategorikal
#
# Metode median dipilih karena lebih stabil terhadap outlier.

# %%
df['luas_m2'] = df['luas_m2'].fillna(df['luas_m2'].median())

df['harga_juta'] = df['harga_juta'].fillna(df['harga_juta'].median())

df['kamar'] = df['kamar'].fillna(df['kamar'].mode()[0])

print("✅ Missing values berhasil ditangani")
# Out:
# ✅ Missing values berhasil ditangani

# %% [markdown]
# # 🔹 STEP 7 - Menangani Outlier
#
# Outlier adalah nilai yang terlalu jauh dari distribusi data normal.
#
# Pada praktikum ini digunakan metode **IQR (Interquartile Range)** untuk membatasi nilai ekstrem.

# %%
for col in ['harga_juta', 'luas_m2']:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df[col] = df[col].clip(lower, upper)

print("✅ Outlier berhasil ditangani")
# Out:
# ✅ Outlier berhasil ditangani

# %% [markdown]
# ### 📌 Penyesuaian Tahun Bangun
#
# Dataset memiliki beberapa nilai tahun bangun yang tidak realistis.
#
# Nilai minimum tahun dibatasi menjadi 1950.

# %%
df['tahun_bangun'] = df['tahun_bangun'].clip(lower=1950)

# %% [markdown]
# # 🔹 STEP 8 - Validasi Data
#
# Validasi dilakukan untuk memastikan:
# - Tidak ada missing values
# - Tidak ada data duplikat
# - Dataset siap digunakan

# %%
print("Total Missing Values :", df.isnull().sum().sum())

print("Total Duplikat :", df.duplicated().sum())

print("Shape Dataset :", df.shape)
# Out:
# Total Missing Values : 0
# Total Duplikat : 0
# Shape Dataset : (130, 7)

# %% [markdown]
# # 🔹 STEP 9 - Export Dataset
#
# Dataset yang sudah bersih disimpan ke file baru bernama `housing_clean.csv`.

# %%
df.to_csv('housing_clean.csv', index=False)

print("✅ Dataset berhasil disimpan")
# Out:
# ✅ Dataset berhasil disimpan

# %% [markdown]
# # 🔹 STEP 10 - Mengakses API JSONPlaceholder
#
# Pada tahap ini dilakukan pengambilan data dari API menggunakan pandas.
#
# Data JSON kemudian diubah menjadi DataFrame.

# %%
url_api = "https://jsonplaceholder.typicode.com/posts"

api_data = pd.read_json(url_api)

api_data.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %% [markdown]
# # 📊 Kesimpulan
#
# Proses data cleaning berhasil dilakukan pada dataset housing.
#
# Tahapan yang dilakukan:
# ✅ Menghapus duplikat
# ✅ Menangani missing values
# ✅ Normalisasi string
# ✅ Menangani outlier
# ✅ Validasi dataset
#
# Dataset akhir sudah bersih dan siap digunakan untuk proses analisis data.

# %% [markdown]
# # 🎯 Preview Dataset Bersih
# Berikut adalah tampilan dataset setelah proses data cleaning selesai dilakukan.

# %%
df.head(10)
# Out:
#    id  luas_m2  harga_juta        kota  kamar  tahun_bangun      kondisi
# 0   1    297.0      1084.0       Jogja    2.0          2000         baik
# 1   2    254.0       761.0       Medan    1.0          1995        bagus
# 2   3    249.7       895.0       Depok    1.0          1983         baik
# 3   4     49.7       178.0         Ygy    5.0          2013         baik
# 4   5    133.4       424.0       Medan    5.0          2004       sedang
# 5   6    153.3       814.0     Jakarta    1.0          2006       sedang
# 6   7    114.3       655.0     Jakarta    3.0          2011         baik
# 7   8    193.8       333.0  Yogyakarta    1.0          1989  baik sekali
# 8   9     81.2       307.0  Yogyakarta    1.0          1996       sedang
# 9  10     69.1       237.0     Bandung    5.0          1980         baik
